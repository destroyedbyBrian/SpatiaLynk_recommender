# %%
import pandas as pd
import numpy as np
from typing import Dict, List, Set, Tuple
from collections import defaultdict
import json

# %%
class POITreeBuilder:
    def __init__(self, csv_file: str):
        """
        Initialize POI Tree Builder
        
        Args:
            csv_file: Path to CSV with columns:
                     name, category, latitude, longitude, district, street, 
                     price, popularity, characteristic, region
        """
        self.df = pd.read_csv(csv_file)
        self.df.columns = ['name', 'category', 'latitude', 'longitude', 
                          'district', 'street', 'price', 'popularity', 
                          'characteristic', 'region']
        
        # Container detection keywords
        self.CONTAINER_KEYWORDS = {
            "mall", "centre", "plaza", "tower", "hub", "center", "city", 
            "junction", "terminal", "complex", "central", "point", "square", 
            "village", "orchard", "building", "galleria", "arcade", "emporium"
        }
        
        self.CONTAINER_CATEGORIES = {
            "shopping_mall", "university", "hospital", "airport", "station",
            "stadium", "convention_center", "hotel"
        }
        
        self.tree = {
            'level_0': {},  # Individual POIs
            'level_1': {},  # Container POIs / Street clusters
            'level_2': {},  # Districts
            'level_3': {}   # Regions
        }
        
        self.container_pois = set()
        self.individual_pois = set()
        self.poi_to_container_map = {}
        
    def detect_containers(self) -> Set[str]:
        """
        Detect which POIs are containers using multiple strategies
        
        Returns:
            Set of container POI names
        """
        containers = set()
        
        # Strategy 1: Check name for container keywords
        for idx, row in self.df.iterrows():
            name_lower = str(row['name']).lower()
            if any(keyword in name_lower for keyword in self.CONTAINER_KEYWORDS):
                containers.add(row['name'])
                print(f"Container detected (keyword): {row['name']}")
        
        # Strategy 2: Check category
        category_containers = self.df[
            self.df['category'].isin(self.CONTAINER_CATEGORIES)
        ]['name'].tolist()
        containers.update(category_containers)
        for name in category_containers:
            print(f"Container detected (category): {name}")
        
        # Strategy 3: Check if POI name appears in street/address column
        all_streets = self.df['street'].dropna().unique()
        for street in all_streets:
            # Check if this street value matches any POI name
            matching_pois = self.df[
                self.df['name'].str.lower() == str(street).lower()
            ]['name'].tolist()
            
            if matching_pois:
                containers.update(matching_pois)
                print(f"Container detected (in address): {matching_pois[0]}")
            
            # Also check partial matches (e.g., "Suntec City" in street)
            for idx, row in self.df.iterrows():
                poi_name = str(row['name'])
                if poi_name not in containers and len(poi_name) > 5:
                    if poi_name.lower() in str(street).lower():
                        containers.add(poi_name)
                        print(f"Container detected (partial match): {poi_name}")
        
        return containers
    
    def map_pois_to_containers(self) -> Dict[str, str]:
        """
        Map individual POIs to their container POIs
        
        Returns:
            Dictionary mapping individual POI name -> container POI name
        """
        poi_container_map = {}
        
        for idx, row in self.df.iterrows():
            poi_name = row['name']
            street = str(row['street'])
            
            # Skip if this POI is itself a container
            if poi_name in self.container_pois:
                continue
            
            # Check if street matches a container POI name
            for container in self.container_pois:
                # Exact match
                if container.lower() == street.lower():
                    poi_container_map[poi_name] = container
                    break
                # Partial match (container name in street)
                elif container.lower() in street.lower() and len(container) > 5:
                    poi_container_map[poi_name] = container
                    break
                # Check if POI and container are at same location (within 50m)
                container_row = self.df[self.df['name'] == container].iloc[0]
                distance = self._haversine_distance(
                    row['latitude'], row['longitude'],
                    container_row['latitude'], container_row['longitude']
                )
                if distance < 0.05:  # Within 50 meters
                    poi_container_map[poi_name] = container
                    break
        
        return poi_container_map
    
    def _haversine_distance(self, lat1: float, lon1: float, 
                           lat2: float, lon2: float) -> float:
        """
        Calculate distance between two coordinates in kilometers
        """
        from math import radians, sin, cos, sqrt, atan2
        
        R = 6371  # Earth's radius in km
        
        lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
        dlat = lat2 - lat1
        dlon = lon2 - lon1
        
        a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
        c = 2 * atan2(sqrt(a), sqrt(1-a))
        
        return R * c
    
    def build_level_0(self):
        """Build Level 0: Individual POIs"""
        print("\n=== Building Level 0: Individual POIs ===")
        
        for idx, row in self.df.iterrows():
            poi_name = row['name']
            
            # Skip containers at this level
            if poi_name in self.container_pois:
                continue
            
            poi_id = f"poi_{idx}_{poi_name.replace(' ', '_')}"
            
            # Determine parent (container or street cluster)
            parent_id = None
            if poi_name in self.poi_to_container_map:
                container_name = self.poi_to_container_map[poi_name]
                parent_id = f"container_{container_name.replace(' ', '_')}"
            else:
                # Use street as parent
                street_district = f"{row['street']}_{row['district']}"
                parent_id = f"street_{street_district.replace(' ', '_')}"
            
            self.tree['level_0'][poi_id] = {
                'name': poi_name,
                'type': 'individual_poi',
                'parent': parent_id,
                'data': {
                    'category': row['category'],
                    'latitude': row['latitude'],
                    'longitude': row['longitude'],
                    'district': row['district'],
                    'street': row['street'],
                    'price': row['price'],
                    'popularity': row['popularity'],
                    'characteristic': row['characteristic'],
                    'region': row['region']
                },
                'spatial': (row['latitude'], row['longitude']),
                'textual': f"{row['name']} {row['category']} {row['characteristic']}"
            }
            
            self.individual_pois.add(poi_name)
        
        print(f"Created {len(self.tree['level_0'])} individual POIs")
    
    def build_level_1(self):
        """Build Level 1: Container POIs and Street Clusters"""
        print("\n=== Building Level 1: Containers & Street Clusters ===")
        
        # First, add container POIs
        for idx, row in self.df.iterrows():
            poi_name = row['name']
            
            if poi_name not in self.container_pois:
                continue
            
            container_id = f"container_{poi_name.replace(' ', '_')}"
            
            # Find all children (individual POIs inside this container)
            children = [
                poi_id for poi_id, poi_data in self.tree['level_0'].items()
                if poi_data['parent'] == container_id
            ]
            
            # Aggregate textual features from children
            child_texts = [
                self.tree['level_0'][child]['textual'] 
                for child in children
            ]
            aggregated_text = f"{poi_name} {row['category']} {row['characteristic']} " + " ".join(child_texts)
            
            # Parent is district
            parent_id = f"district_{row['district'].replace(' ', '_')}_{row['region'].replace(' ', '_')}"
            
            self.tree['level_1'][container_id] = {
                'name': poi_name,
                'type': 'container_poi',
                'parent': parent_id,
                'children': children,
                'data': {
                    'category': row['category'],
                    'latitude': row['latitude'],
                    'longitude': row['longitude'],
                    'district': row['district'],
                    'street': row['street'],
                    'region': row['region'],
                    'num_entities': len(children)
                },
                'spatial': (row['latitude'], row['longitude']),
                'textual': aggregated_text
            }
        
        # Second, create street clusters for POIs without containers
        street_clusters = defaultdict(list)
        
        for poi_id, poi_data in self.tree['level_0'].items():
            if poi_data['parent'].startswith('street_'):
                street_clusters[poi_data['parent']].append(poi_id)
        
        for street_id, children in street_clusters.items():
            # Calculate centroid
            lats = [self.tree['level_0'][child]['spatial'][0] for child in children]
            lons = [self.tree['level_0'][child]['spatial'][1] for child in children]
            centroid = (np.mean(lats), np.mean(lons))
            
            # Get district and region from first child
            first_child = self.tree['level_0'][children[0]]
            district = first_child['data']['district']
            region = first_child['data']['region']
            street = first_child['data']['street']
            
            # Aggregate text
            child_texts = [self.tree['level_0'][child]['textual'] for child in children]
            aggregated_text = f"{street} " + " ".join(child_texts)
            
            parent_id = f"district_{district.replace(' ', '_')}_{region.replace(' ', '_')}"
            
            self.tree['level_1'][street_id] = {
                'name': street,
                'type': 'street_cluster',
                'parent': parent_id,
                'children': children,
                'data': {
                    'district': district,
                    'region': region,
                    'num_entities': len(children)
                },
                'spatial': centroid,
                'textual': aggregated_text
            }
        
        print(f"Created {len(self.tree['level_1'])} Level 1 nodes "
              f"({len([n for n in self.tree['level_1'].values() if n['type'] == 'container_poi'])} containers, "
              f"{len([n for n in self.tree['level_1'].values() if n['type'] == 'street_cluster'])} street clusters)")
    
    def build_level_2(self):
        """Build Level 2: Districts"""
        print("\n=== Building Level 2: Districts ===")
        
        district_data = defaultdict(lambda: {
            'children': [],
            'pois': [],
            'spatial_coords': [],
            'texts': []
        })
        
        # Aggregate from level 1
        for node_id, node_data in self.tree['level_1'].items():
            district = node_data['data']['district']
            region = node_data['data']['region']
            district_key = f"district_{district.replace(' ', '_')}_{region.replace(' ', '_')}"
            
            district_data[district_key]['children'].append(node_id)
            district_data[district_key]['spatial_coords'].append(node_data['spatial'])
            district_data[district_key]['texts'].append(node_data['textual'])
            district_data[district_key]['district'] = district
            district_data[district_key]['region'] = region
        
        # Create district nodes
        for district_id, data in district_data.items():
            # Calculate centroid
            lats = [coord[0] for coord in data['spatial_coords']]
            lons = [coord[1] for coord in data['spatial_coords']]
            centroid = (np.mean(lats), np.mean(lons))
            
            # Aggregate text
            aggregated_text = f"{data['district']} " + " ".join(data['texts'])
            
            parent_id = f"region_{data['region'].replace(' ', '_')}"
            
            self.tree['level_2'][district_id] = {
                'name': data['district'],
                'type': 'district',
                'parent': parent_id,
                'children': data['children'],
                'data': {
                    'region': data['region'],
                    'num_level1_nodes': len(data['children'])
                },
                'spatial': centroid,
                'textual': aggregated_text
            }
        
        print(f"Created {len(self.tree['level_2'])} districts")
    
    def build_level_3(self):
        """Build Level 3: Regions"""
        print("\n=== Building Level 3: Regions ===")
        
        region_data = defaultdict(lambda: {
            'children': [],
            'spatial_coords': [],
            'texts': []
        })
        
        # Aggregate from level 2
        for district_id, district_node in self.tree['level_2'].items():
            region = district_node['data']['region']
            region_key = f"region_{region.replace(' ', '_')}"
            
            region_data[region_key]['children'].append(district_id)
            region_data[region_key]['spatial_coords'].append(district_node['spatial'])
            region_data[region_key]['texts'].append(district_node['textual'])
            region_data[region_key]['region'] = region
        
        # Create region nodes
        for region_id, data in region_data.items():
            # Calculate centroid
            lats = [coord[0] for coord in data['spatial_coords']]
            lons = [coord[1] for coord in data['spatial_coords']]
            centroid = (np.mean(lats), np.mean(lons))
            
            # Aggregate text
            aggregated_text = f"{data['region']} " + " ".join(data['texts'])
            
            self.tree['level_3'][region_id] = {
                'name': data['region'],
                'type': 'region',
                'parent': None,  # Top level
                'children': data['children'],
                'data': {
                    'num_districts': len(data['children'])
                },
                'spatial': centroid,
                'textual': aggregated_text
            }
        
        print(f"Created {len(self.tree['level_3'])} regions")
    
    def build(self) -> Dict:
        """
        Build complete POI tree
        
        Returns:
            Complete tree structure
        """
        print("="*60)
        print("Starting POI Tree Construction")
        print("="*60)
        
        # Step 1: Detect containers
        print("\n=== Step 1: Container Detection ===")
        self.container_pois = self.detect_containers()
        print(f"\nTotal containers found: {len(self.container_pois)}")
        
        # Step 2: Map POIs to containers
        print("\n=== Step 2: Mapping POIs to Containers ===")
        self.poi_to_container_map = self.map_pois_to_containers()
        print(f"Mapped {len(self.poi_to_container_map)} POIs to containers")
        
        # Step 3: Build hierarchy levels
        self.build_level_0()
        self.build_level_1()
        self.build_level_2()
        self.build_level_3()
        
        print("\n" + "="*60)
        print("POI Tree Construction Complete!")
        print("="*60)
        self.print_summary()
        
        return self.tree
    
    def print_summary(self):
        """Print tree statistics"""
        print(f"\nTree Summary:")
        print(f"  Level 0 (Individual POIs): {len(self.tree['level_0'])} nodes")
        print(f"  Level 1 (Containers/Streets): {len(self.tree['level_1'])} nodes")
        print(f"  Level 2 (Districts): {len(self.tree['level_2'])} nodes")
        print(f"  Level 3 (Regions): {len(self.tree['level_3'])} nodes")
        print(f"  Total nodes: {sum(len(level) for level in self.tree.values())}")
    
    def save_tree(self, output_file: str = 'poi_tree.json'):
        """Save tree to JSON file"""
        # Convert to serializable format
        serializable_tree = {}
        for level, nodes in self.tree.items():
            serializable_tree[level] = {}
            for node_id, node_data in nodes.items():
                serializable_tree[level][node_id] = {
                    k: (str(v) if isinstance(v, (np.floating, np.integer)) else v)
                    for k, v in node_data.items()
                }
        
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(serializable_tree, f, indent=2, ensure_ascii=False)
        
        print(f"\nTree saved to {output_file}")
    
    def visualize_sample(self, num_samples: int = 3):
        """Print sample tree paths"""
        print(f"\n=== Sample Tree Paths ===")
        
        sample_pois = list(self.tree['level_0'].keys())[:num_samples]
        
        for poi_id in sample_pois:
            path = [f"L0: {self.tree['level_0'][poi_id]['name']}"]
            
            # Level 1
            parent_l1 = self.tree['level_0'][poi_id]['parent']
            if parent_l1 in self.tree['level_1']:
                path.append(f"L1: {self.tree['level_1'][parent_l1]['name']} "
                          f"({self.tree['level_1'][parent_l1]['type']})")
                
                # Level 2
                parent_l2 = self.tree['level_1'][parent_l1]['parent']
                if parent_l2 in self.tree['level_2']:
                    path.append(f"L2: {self.tree['level_2'][parent_l2]['name']}")
                    
                    # Level 3
                    parent_l3 = self.tree['level_2'][parent_l2]['parent']
                    if parent_l3 in self.tree['level_3']:
                        path.append(f"L3: {self.tree['level_3'][parent_l3]['name']}")
            
            print("\n" + " → ".join(reversed(path)))
    
    def get_node_by_name(self, name: str, level: int = None):
        """
        Find node by name
        
        Args:
            name: POI name
            level: Optional level to search in (0-3)
        
        Returns:
            (node_id, node_data, level) or None
        """
        levels_to_search = [f'level_{level}'] if level is not None else self.tree.keys()
        
        for level_key in levels_to_search:
            for node_id, node_data in self.tree[level_key].items():
                if node_data['name'].lower() == name.lower():
                    return (node_id, node_data, level_key)
        
        return None
    
    def get_ancestors(self, node_id: str, current_level: str) -> List[Tuple]:
        """
        Get all ancestor nodes
        
        Returns:
            List of (node_id, node_data, level) tuples
        """
        ancestors = []
        
        level_num = int(current_level.split('_')[1])
        current_node = self.tree[current_level][node_id]
        
        while current_node.get('parent') and level_num < 3:
            level_num += 1
            next_level = f'level_{level_num}'
            parent_id = current_node['parent']
            
            if parent_id in self.tree[next_level]:
                current_node = self.tree[next_level][parent_id]
                ancestors.append((parent_id, current_node, next_level))
            else:
                break
        
        return ancestors
    
    def get_descendants(self, node_id: str, current_level: str) -> List[Tuple]:
        """
        Get all descendant nodes (recursive)
        
        Returns:
            List of (node_id, node_data, level) tuples
        """
        descendants = []
        
        def _recurse(nid, lvl):
            level_num = int(lvl.split('_')[1])
            if level_num == 0:
                return
            
            node = self.tree[lvl][nid]
            if 'children' in node:
                child_level = f'level_{level_num - 1}'
                for child_id in node['children']:
                    if child_id in self.tree[child_level]:
                        child_node = self.tree[child_level][child_id]
                        descendants.append((child_id, child_node, child_level))
                        _recurse(child_id, child_level)
        
        _recurse(node_id, current_level)
        return descendants

# %%
if __name__ == "__main__":
    builder = POITreeBuilder('POI_with_region.csv')
    POI_tree = builder.build()

    builder.save_tree('poi_tree.json')
    builder.visualize_sample(num_samples=5)

    result = builder.get_node_by_name("Din Tai Fung")
    if result:
        node_id, node_data, level = result
        print(f"\nFound 'Din Tai Fung' at {level}")
        print(f"  Location: {node_data['spatial']}")
        print(f"  Parent: {node_data['parent']}")
        
        # Get ancestors
        ancestors = builder.get_ancestors(node_id, level)
        print(f"  Ancestors: {[a[1]['name'] for a in ancestors]}")
    
    # Find a container
    result = builder.get_node_by_name("Suntec City")
    if result:
        node_id, node_data, level = result
        print(f"\nFound 'Suntec City' at {level}")
        print(f"  Type: {node_data['type']}")
        print(f"  Children: {len(node_data.get('children', []))}")
        
        # Get descendants
        descendants = builder.get_descendants(node_id, level)
        print(f"  Total descendants: {len(descendants)}")
# Out:
# ============================================================
# Starting POI Tree Construction
# ============================================================
#
# === Step 1: Container Detection ===
# Container detected (keyword): Good Price Centre
# Container detected (keyword): Starhub
# Container detected (keyword): The Poiz Centre
# Container detected (keyword): Clarke Quay Central
# Container detected (keyword): Changi Airport Terminal 1
# Container detected (keyword): Sim Lim Square
# Container detected (keyword): Broadway Plaza
# Container detected (keyword): Rivervale Plaza
# Container detected (keyword): Rivervale Mall
# Container detected (keyword): Hougang Mall
# Container detected (keyword): Heartland Mall
# Container detected (keyword): Jubilee Square
# Container detected (keyword): Raffles City Shopping Centre
# Container detected (keyword): Orchard Central
# Container detected (keyword): Orchard Towers
# Container detected (keyword): Anchorpoint
# Container detected (keyword): Cathay Cineleisure Orchard
# Container detected (keyword): Katong Plaza
# Container detected (keyword): Katong Shopping Centre
# Container detected (keyword): Odeon Katong Shopping Complex
# Container detected (keyword): Bras Basah Complex
# Container detected (keyword): Roxy Square
# Container detected (keyword): Orchard Plaza
# Container detected (keyword): The Centrepoint
# Container detected (keyword): Ngee Ann City
# Container detected (keyword): Pacific Plaza
# Container detected (keyword): Parklane Shopping Mall
# Container detected (keyword): Sunshine Plaza
# Container detected (keyword): Fortune Centre
# Container detected (keyword): Peninsula Plaza
# Container detected (keyword): Suntec City
# Container detected (keyword): Tanglin Mall
# Container detected (keyword): East Point
# Container detected (keyword): Tanjong Katong Complex
# Container detected (keyword): City Plaza
# Container detected (keyword): Tekka Centre
# Container detected (keyword): Mustafa Centre
# Container detected (keyword): Sun Plaza
# Container detected (keyword): Depot Heights Shopping Centre
# Container detected (keyword): Sembawang Shopping Centre
# Container detected (keyword): Causeway Point
# Container detected (keyword): Simei Plaza /Blk 248
# Container detected (keyword): Pioneer Mall
# Container detected (keyword): Gek Poh Shopping Centre
# Container detected (keyword): City Square Mall
# Container detected (keyword): Alexandra Central
# Container detected (keyword): Old Airport Road Food Centre & Shopping Mall
# Container detected (keyword): Djitsun Mall Bedok
# Container detected (keyword): Thomson Plaza
# Container detected (keyword): Bukit Timah Shopping Center
# Container detected (keyword): Beauty World Centre
# Container detected (keyword): Beauty World Plaza
# Container detected (keyword): The Clementi Mall
# Container detected (keyword): Grantral Mall  Clementi
# Container detected (keyword): Upper Serangoon Shopping Centre
# Container detected (keyword): West Coast Plaza
# Container detected (keyword): Icon Village
# Container detected (keyword): Ang Mo Kio Hub
# Container detected (keyword): Delfi Orchard
# Container detected (keyword): Orchard Building
# Container detected (keyword): Coronation Plaza
# Container detected (keyword): Great World City
# Container detected (keyword): Tampines Mall
# Container detected (keyword): Century Square
# Container detected (keyword): Rochester Mall
# Container detected (keyword): HDB Hub
# Container detected (keyword): Concorde Shopping Centre
# Container detected (keyword): Tiong Bahru Plaza
# Container detected (keyword): Bugis Junction
# Container detected (keyword): Far East Shopping Centre
# Container detected (keyword): Forum The Shopping Mall
# Container detected (keyword): Liat Tower
# Container detected (keyword): Lucky Plaza
# Container detected (keyword): Tang Plaza
# Container detected (keyword): Velocity  Novena Square
# Container detected (keyword): Square 2
# Container detected (keyword): United Square
# Container detected (keyword): Changi Airport Terminal 2
# Container detected (keyword): Changi Airport Terminal 3
# Container detected (keyword): Lot One Shoppers Mall
# Container detected (keyword): Mustafa Centre
# Container detected (keyword): Mustafa Centre
# Container detected (keyword): Mustafa Centre
# Container detected (keyword): Midpoint Orchard
# Container detected (keyword): Orchard Gateway
# Container detected (keyword): Shaw Plaza
# Container detected (keyword): Loyang Point
# Container detected (keyword): Punggol Plaza
# Container detected (keyword): Paya Lebar Square
# Container detected (keyword): YewTee Point
# Container detected (keyword): ION Orchard
# Container detected (keyword): The Seletar Mall
# Container detected (keyword): Limbang Shopping Centre
# Container detected (keyword): Junction 10
# Container detected (keyword): Jurong Point
# Container detected (keyword): Bugis Junction
# Container detected (keyword): Orchard Shopping Centre
# Container detected (keyword): Zhongshan Mall
# Container detected (keyword): Orchard Gateway  Emerald
# Container detected (keyword): Waterway Point
# Container detected (keyword): Marina Square
# Container detected (keyword): myVillage
# Container detected (keyword): Jalan Besar Plaza
# Container detected (keyword): Balestier Plaza
# Container detected (keyword): Roxy Square
# Container detected (keyword): Fairprice Hub
# Container detected (keyword): Guoco Tower
# Container detected (keyword): Buangkok Square Mall
# Container detected (keyword): Northshore Plaza II
# Container detected (keyword): Wisteria Mall
# Container detected (keyword): Aperia Mall
# Container detected (keyword): MacPherson Mall
# Container detected (keyword): Marsiling Mall Hawker Centre
# Container detected (keyword): Plaza Singapura
# Container detected (keyword): Katong Square
# Container detected (keyword): The Flow Mall
# Container detected (keyword): Junction 8
# Container detected (keyword): Design Orchard
# Container detected (keyword): Bedok Mall
# Container detected (keyword): Clarke Quay Central
# Container detected (keyword): Northpoint City
# Container detected (keyword): Canberra Plaza
# Container detected (keyword): Alexandra Retail Centre
# Container detected (keyword): Plantation Plaza
# Container detected (keyword): The Woodleigh Mall
# Container detected (keyword): Sengkang Grand Mall
# Container detected (keyword): Pasir Ris Mall
# Container detected (keyword): Eastlink Mall
# Container detected (keyword): One Holland Village
# Container detected (keyword): Taman Jurong Shopping Centre
# Container detected (keyword): VivoCity
# Container detected (keyword): Boon Lay Shopping Centre
# Container detected (keyword): Elias Mall
# Container detected (keyword): Keat Hong Shopping Centre
# Container detected (keyword): Bedok Mall
# Container detected (keyword): Velocity  Novena Square
# Container detected (keyword): Northshore Plaza I
# Container detected (keyword): Concorde Shopping Centre
# Container detected (keyword): Gain City
# Container detected (keyword): Sony Centre
# Container detected (keyword): Gain City Megastore
# Container detected (keyword): Jewellery City Co. Pte Ltd
# Container detected (keyword): Books Kinokuniya Bugis Junction Store
# Container detected (keyword): Katong Catholic Book Centre
# Container detected (keyword): Oxley bizhub 2
# Container detected (keyword): Kian Joo Vegetarian Food Supply Centre .
# Container detected (keyword): Don Don Donki Clarke Quay Central
# Container detected (keyword): Workspace Expresso Bar Novena Square
# Container detected (keyword): Peoples Park Centre
# Container detected (keyword): Central Hong Kong Caf
# Container detected (keyword): Genius Central
# Container detected (keyword): Hub & Spoke Cafe
# Container detected (keyword): Central Hong Kong Caf
# Container detected (keyword): Park  Holland Village
# Container detected (keyword): Empress Road Food Centre
# Container detected (keyword): Lorong 4 Blk 93 Market and Hawker Centre
# Container detected (keyword): Ghim Moh Road Food Centre
# Container detected (keyword): Tekka Food Centre
# Container detected (keyword): Holland Village XO Fish Head Bee Hoon Restaurant
# Container detected (keyword): Sichuan Village Restaurant
# Container detected (keyword): Rhubarb
# Container detected (keyword): Jumbo Seafood (Riverside Point)
# Container detected (keyword): Ci Yuan Hawker Centre
# Container detected (keyword): Jacks Place (Great World City)
# Container detected (keyword): Cedele (Great World City)
# Container detected (keyword): Ponggol Nasi Lemak Centre
# Container detected (keyword): Aui Food Centre
# Container detected (keyword): Small Seaf and BBQ
# Container detected (keyword): K-Tower
# Container detected (keyword): Kola Food Centre
# Container detected (keyword): Plum Village Restaurant
# Container detected (keyword): Toss & Turn Vivo City
# Container detected (keyword): Beancurd City
# Container detected (keyword): Curry Village
# Container detected (keyword): Shing Boon Hwa Food Centre
# Container detected (keyword): Green Vegetarian inside Koufu food court Yew Tee Point - Basement  B1 (near Yew Tee MRT)
# Container detected (keyword): Xian Seafood Village
# Container detected (keyword): Xian Seafood Village
# Container detected (keyword): Holland Village XO Fish Head Mee Hoon
# Container detected (keyword): Ayer Rajah Food Centre
# Container detected (keyword): Good Year Seafood Village
# Container detected (keyword): Happy Seafood Village
# Container detected (keyword): Yolo Icon Village
# Container detected (keyword): Food Junction
# Container detected (keyword): Dover Village XO Fishhead Bee Hoon
# Container detected (keyword): iSTEAKS  myVillage
# Container detected (keyword): Siam Village
# Container detected (keyword): Soon Li Whitley Food Centre Pork Porridge
# Container detected (keyword): SoupCup Suntec City
# Container detected (keyword): City Hot Pot
# Container detected (keyword): Pioneer Food Village
# Container detected (keyword): Food Centre
# Container detected (keyword): Food Centre
# Container detected (keyword): Food Centre
# Container detected (keyword): Small Batch
# Container detected (keyword): MOS CAF Raffles City
# Container detected (keyword): Bakery Point
# Container detected (keyword): Dover Medical Centre
# Container detected (keyword): SATA CommHealth Uttamram Medical Centre
# Container detected (keyword): Thomson Womens Centre
# Container detected (keyword): ECM X-Ray Centre PTE LTD
# Container detected (keyword): Central Clinic
# Container detected (keyword): Central 24-Hr Clinic (Hougang)
# Container detected (keyword): FHC Dialysis Centre Pte Ltd
# Container detected (keyword): Nam Ann Siang Theon Medical Centre
# Container detected (keyword): Tiong Bahru Medical Centre
# Container detected (keyword): Eastern Medical Centre
# Container detected (keyword): SATA CommHealth Potong Pasir Medical Centre
# Container detected (keyword): Mandarin Central & Dental Centre
# Container detected (keyword): Clementi Family Healthpoint Clinic & Surgery
# Container detected (keyword): AMK Specialist Centre
# Container detected (keyword): Q&M Dental Center (Balestier)
# Container detected (keyword): St John Singapore Dementia Centre
# Container detected (keyword): HC Endoscopy & Piles Centre
# Container detected (keyword): Fullerton Health Hub
# Container detected (keyword): Sungei Gedong Medical Centre
# Container detected (keyword): Camden Medical Centre
# Container detected (keyword): International Dental Centre
# Container detected (keyword): Smilepoint
# Container detected (keyword): Q&M Dental Centre (River Valley)
# Container detected (keyword): Family Dental Centre
# Container detected (keyword): LVDA Dental Centre
# Container detected (keyword): Q&M Dental Centre
# Container detected (keyword): Mandarin Dental Centre
# Container detected (keyword): B9 Dental Centre (Clementi)
# Container detected (keyword): GPA Dental  Parkview Square
# Container detected (keyword): National Cancer Centre Singapore Proton Therapy Centre
# Container detected (keyword): Priya Sen Skin & Laser Centre
# Container detected (keyword): StarMed Specialist Centre
# Container detected (keyword): Jurong West Joint Testing & Vaccination Centre
# Container detected (keyword): Jurong East Joint Testing & Vaccination Centre
# Container detected (keyword): Pasir Ris Joint Testing & Vaccination Centre
# Container detected (keyword): National Kidney Foundation Dialysis Centre
# Container detected (keyword): Ang Mo Kio Joint Testing & Vaccination Centre
# Container detected (keyword): ECM Building
# Container detected (keyword): Bukit Merah Joint Testing & Vaccination Centre
# Container detected (keyword): Sengkang Joint Testing & Vaccination Centre
# Container detected (keyword): Tan Tock Seng Hospital Integrated Care Hub
# Container detected (keyword): UFIT CBD Hub
# Container detected (keyword): Admin Building
# Container detected (keyword): Hotel Grand Central
# Container detected (keyword): Hotel Jen (Orchardgateway)
# Container detected (keyword): Orchard Hotel Singapore
# Container detected (keyword): Orchard RendezVous Hotel
# Container detected (keyword): Dorsett Changi City Singapore
# Container detected (keyword): Crowne Plaza (Changi Airport)
# Container detected (keyword): Holiday Inn (Orchard City Centre)
# Container detected (keyword): Holiday Inn Express (Orchard Road)
# Container detected (keyword): Hilton Singapore Orchard
# Container detected (keyword): Grand Park City Hall
# Container detected (keyword): Pullman Singapore Orchard
# Container detected (keyword): River City Inn
# Container detected (keyword): Royal Plaza
# Container detected (keyword): Sheraton Towers Singapore
# Container detected (keyword): Singapore Marriott Tang Plaza Hotel
# Container detected (keyword): Vibe Hotel Singapore Orchard
# Container detected (keyword): ChancellorOrchard
# Container detected (keyword): Sofitel Singapore City Centre
# Container detected (keyword): Mercure ICON Singapore City Centre
# Container detected (keyword): Hotel Grand Central
# Container detected (keyword): Holiday Inn Singapore Orchard City Centre
# Container detected (keyword): Yotel Singapore Orchard Road
# Container detected (keyword): Pan Pacific Orchard
# Container detected (keyword): Crockfords Tower
# Container detected (keyword): Ji Hotel Orchard
# Container detected (keyword): voco Orchard Singapore
# Container detected (keyword): Champion Hotel City
# Container detected (keyword): Village Hotel (Changi)
# Container detected (keyword): Village Hotel (Bugis)
# Container detected (keyword): Village Hotel (Katong)
# Container detected (keyword): Orchard Hills Residences Singapore MGallery
# Container detected (keyword): Conrad Singapore Orchard
# Container detected (keyword): Carlton City Hotel
# Container detected (keyword): Ascott Orchard Singapore
# Container detected (keyword): Novotel Living Singapore Orchard
# Container detected (keyword): Village Hotel  Sentosa
# Container detected (keyword): Village Hotel Albert Court
# Container detected (keyword): Central 65 Hostel & Cafe
# Container detected (keyword): City Backpackers
# Container detected (keyword): Certis Cisco west hub
# Container detected (keyword): POSB Serangoon Central Branch
# Container detected (keyword): Orchard Credit
# Container detected (keyword): Citi Wealth Hub
# Container detected (keyword): OCBC Centre
# Container detected (keyword): Bank of Singapore Centre
# Container detected (keyword): Indian Overseas Bank Building
# Container detected (keyword): WeWork Suntec Tower 5
# Container detected (keyword): The Executive Centre MBFC Tower 1
# Container detected (category): The Star Vista
# Container detected (category): Katong V
# Container detected (category): The Poiz Centre
# Container detected (category): Clarke Quay Central
# Container detected (category): Changi Airport Terminal 1
# Container detected (category): Sim Lim Square
# Container detected (category): Broadway Plaza
# Container detected (category): Compass One
# Container detected (category): Rivervale Plaza
# Container detected (category): Rivervale Mall
# Container detected (category): Hougang Mall
# Container detected (category): Heartland Mall
# Container detected (category): IMM
# Container detected (category): White Sands
# Container detected (category): Jubilee Square
# Container detected (category): Raffles City Shopping Centre
# Container detected (category): Shaw House
# Container detected (category): Orchard Central
# Container detected (category): Palais Renaissance
# Container detected (category): Orchard Towers
# Container detected (category): Anchorpoint
# Container detected (category): Cathay Cineleisure Orchard
# Container detected (category): 100AM
# Container detected (category): Parkway Parade
# Container detected (category): i12 Katong
# Container detected (category): Katong Plaza
# Container detected (category): Katong Shopping Centre
# Container detected (category): Odeon Katong Shopping Complex
# Container detected (category): Bras Basah Complex
# Container detected (category): Roxy Square
# Container detected (category): Orchard Plaza
# Container detected (category): The Centrepoint
# Container detected (category): Ngee Ann City
# Container detected (category): Pacific Plaza
# Container detected (category): Parklane Shopping Mall
# Container detected (category): GR.ID
# Container detected (category): Sunshine Plaza
# Container detected (category): Fortune Centre
# Container detected (category): Peninsula Plaza
# Container detected (category): Suntec City
# Container detected (category): Tanglin Mall
# Container detected (category): East Point
# Container detected (category): Tanjong Katong Complex
# Container detected (category): City Plaza
# Container detected (category): Tekka Centre
# Container detected (category): Mustafa Centre
# Container detected (category): OUE Downtown
# Container detected (category): Bugis
# Container detected (category): Sun Plaza
# Container detected (category): 313Somerset
# Container detected (category): Depot Heights Shopping Centre
# Container detected (category): Sembawang Shopping Centre
# Container detected (category): Causeway Point
# Container detected (category): Simei Plaza /Blk 248
# Container detected (category): Pioneer Mall
# Container detected (category): Gek Poh Shopping Centre
# Container detected (category): City Square Mall
# Container detected (category): The Star Vista
# Container detected (category): Hougang 1
# Container detected (category): Alexandra Central
# Container detected (category): Old Airport Road Food Centre & Shopping Mall
# Container detected (category): Djitsun Mall Bedok
# Container detected (category): Thomson Plaza
# Container detected (category): Bukit Timah Shopping Center
# Container detected (category): Beauty World Centre
# Container detected (category): Beauty World Plaza
# Container detected (category): The Clementi Mall
# Container detected (category): Grantral Mall  Clementi
# Container detected (category): Upper Serangoon Shopping Centre
# Container detected (category): West Coast Plaza
# Container detected (category): Icon Village
# Container detected (category): Ang Mo Kio Hub
# Container detected (category): Admiralty Place
# Container detected (category): Delfi Orchard
# Container detected (category): Orchard Building
# Container detected (category): Tekka Place
# Container detected (category): Westgate
# Container detected (category): Coronation Plaza
# Container detected (category): Great World City
# Container detected (category): Tampines Mall
# Container detected (category): Century Square
# Container detected (category): Tampines 1
# Container detected (category): Rochester Mall
# Container detected (category): HDB Hub
# Container detected (category): Concorde Shopping Centre
# Container detected (category): Tiong Bahru Plaza
# Container detected (category): Bugis Junction
# Container detected (category): Far East Shopping Centre
# Container detected (category): Forum The Shopping Mall
# Container detected (category): Liat Tower
# Container detected (category): Lucky Plaza
# Container detected (category): Paragon
# Container detected (category): Tang Plaza
# Container detected (category): Wisma Atria
# Container detected (category): The Heeren
# Container detected (category): Velocity  Novena Square
# Container detected (category): Square 2
# Container detected (category): United Square
# Container detected (category): Changi Airport Terminal 2
# Container detected (category): Changi Airport Terminal 3
# Container detected (category): Lot One Shoppers Mall
# Container detected (category): Downtown East
# Container detected (category): nex
# Container detected (category): Fusionopolis 1
# Container detected (category): Mustafa Centre
# Container detected (category): Mustafa Centre
# Container detected (category): Mustafa Centre
# Container detected (category): Midpoint Orchard
# Container detected (category): Orchard Gateway
# Container detected (category): Sunshine Place
# Container detected (category): Shaw Plaza
# Container detected (category): Loyang Point
# Container detected (category): Punggol Plaza
# Container detected (category): Paya Lebar Square
# Container detected (category): YewTee Point
# Container detected (category): ION Orchard
# Container detected (category): The Seletar Mall
# Container detected (category): Limbang Shopping Centre
# Container detected (category): Junction 10
# Container detected (category): Jurong Point
# Container detected (category): Bugis Junction
# Container detected (category): Orchard Shopping Centre
# Container detected (category): Zhongshan Mall
# Container detected (category): Orchard Gateway  Emerald
# Container detected (category): Waterway Point
# Container detected (category): Marina Square
# Container detected (category): myVillage
# Container detected (category): Jalan Besar Plaza
# Container detected (category): Balestier Plaza
# Container detected (category): Kinex
# Container detected (category): Roxy Square
# Container detected (category): Fairprice Hub
# Container detected (category): Guoco Tower
# Container detected (category): Buangkok Square Mall
# Container detected (category): Northshore Plaza II
# Container detected (category): Funan
# Container detected (category): Clementi 321
# Container detected (category): Wisteria Mall
# Container detected (category): 18 Tai Seng
# Container detected (category): Wheelock Place
# Container detected (category): Aperia Mall
# Container detected (category): MacPherson Mall
# Container detected (category): Marsiling Mall Hawker Centre
# Container detected (category): Downtown Gallery
# Container detected (category): Plaza Singapura
# Container detected (category): The Oasis
# Container detected (category): Katong Square
# Container detected (category): The Flow Mall
# Container detected (category): Junction 8
# Container detected (category): Design Orchard
# Container detected (category): Bedok Mall
# Container detected (category): Clarke Quay Central
# Container detected (category): Northpoint City
# Container detected (category): Canberra Plaza
# Container detected (category): Jewel Changi Airport
# Container detected (category): Millenia Walk
# Container detected (category): Quayside Isle
# Container detected (category): Quayside Isle
# Container detected (category): Alexandra Retail Centre
# Container detected (category): Plantation Plaza
# Container detected (category): Trio
# Container detected (category): The Woodleigh Mall
# Container detected (category): The Concourse
# Container detected (category): STELLARTE2
# Container detected (category): Sengkang Grand Mall
# Container detected (category): Pasir Ris Mall
# Container detected (category): Eastlink Mall
# Container detected (category): One Holland Village
# Container detected (category): Big Block
# Container detected (category): Taman Jurong Shopping Centre
# Container detected (category): The Shoppes at Marina Bay Sands
# Container detected (category): VivoCity
# Container detected (category): Boon Lay Shopping Centre
# Container detected (category): Elias Mall
# Container detected (category): Keat Hong Shopping Centre
# Container detected (category): Dawson Place
# Container detected (category): Bedok Mall
# Container detected (category): Velocity  Novena Square
# Container detected (category): JEM
# Container detected (category): Northshore Plaza I
# Container detected (category): Concorde Shopping Centre
# Container detected (category): The Woodgrove
# Container detected (category): Cluny Court
# Container detected (category): National Cancer Centre Singapore Proton Therapy Centre
# Container detected (category): Farrer Park Hospital
# Container detected (category): Priya Sen Skin & Laser Centre
# Container detected (category): StarMed Specialist Centre
# Container detected (category): Sengkang General & Community Hospital
# Container detected (category): Changi General Hospital
# Container detected (category): Gleneagles Hospital
# Container detected (category): Raffles Hospital
# Container detected (category): Mount Alvernia Hospital
# Container detected (category): Jurong West Joint Testing & Vaccination Centre
# Container detected (category): Jurong East Joint Testing & Vaccination Centre
# Container detected (category): Bright Vision Hospital
# Container detected (category): Saint Andrews Community Hospital
# Container detected (category): Ren Ci Community Hospital
# Container detected (category): Pasir Ris Joint Testing & Vaccination Centre
# Container detected (category): Mount Elizabeth Novena Hospital
# Container detected (category): National Kidney Foundation Dialysis Centre
# Container detected (category): Ang Mo Kio Joint Testing & Vaccination Centre
# Container detected (category): Jurong Health Specialist Outpatient Clinics
# Container detected (category): Jurong Community Hospital
# Container detected (category): Jurong Health Services
# Container detected (category): Ng Teng Fong General Hospital
# Container detected (category): ECM Building
# Container detected (category): Bukit Merah Joint Testing & Vaccination Centre
# Container detected (category): Sengkang Joint Testing & Vaccination Centre
# Container detected (category): Tan Tock Seng Hospital Integrated Care Hub
# Container detected (category): Khoo Teck Puat Hospital
# Container detected (category): Bidadari Polyclinic & Nursing Home
# Container detected (category): Crawfurd Hospital
# Container detected (category): Tan Tock Seng Hospital
# Container detected (category): Lee Kong Chian School of Medicine (Novena Campus)
# Container detected (category): Admin Building
# Container detected (category): University of the Arts Singapore
# Container detected (category): Republic Polytechnic
# Container detected (category): Former PSB Academy Campus (Delta)
# Container detected (category): Singapore Polytechnic
# Container detected (category): Singapore University of Technology and Design Campus
# Container detected (category): James Cook University Singapore
# Container detected (category): Singapore Polytechnic (Poly Marina)
# Container detected (category): INSEAD Asia
# Container detected (category): National University of Singapore (Bukit Timah)
# Container detected (category): SMF Institute of Higher Learning
# Container detected (category): Singapore Management University
# Container detected (category): Ngee Ann Polytechnic
# Container detected (category): Singapore Institute of Technology (Dover)
# Container detected (category): W Singapore - Sentosa Cove
# Container detected (category): Diamond
# Container detected (category): Dorsett Singapore
# Container detected (category): Fairmont
# Container detected (category): Owen House by Hmlet
# Container detected (category): Four Chain View Hotel
# Container detected (category): Four Seasons Hotel
# Container detected (category): Adamson Lodge
# Container detected (category): Adonis Hotel
# Container detected (category): Amara Singapore
# Container detected (category): ST Signature Coliving Hostel
# Container detected (category): Hotel Clover (The Arts)
# Container detected (category): Hotel Conforto
# Container detected (category): Fuji
# Container detected (category): Hotel Grand Central
# Container detected (category): Harbour Ville Hotel Hamilton
# Container detected (category): Hotel Jen (Orchardgateway)
# Container detected (category): JEN Singapore Tanglin
# Container detected (category): Hotel Kai
# Container detected (category): Hotel Nuve
# Container detected (category): Hotel Re
# Container detected (category): Hotel Royal
# Container detected (category): Hotel Snow
# Container detected (category): Hotel Supreme
# Container detected (category): Hup Hoe Hotel
# Container detected (category): Ibis (Bencoolen)
# Container detected (category): Ibis Styles
# Container detected (category): J8 Hotel
# Container detected (category): Jade
# Container detected (category): Jin Dong Hotel
# Container detected (category): Hotel 1888 Collection
# Container detected (category): Just Inn Pine
# Container detected (category): Kam Leng Hotel
# Container detected (category): Kerbau Hotel
# Container detected (category): Kim Tian (Star) Hotel
# Container detected (category): Kim Tian Hotel (Han)
# Container detected (category): La Mode (Sophia)
# Container detected (category): Lai Ming Hotel Cosmoland
# Container detected (category): The Snooze Hotel
# Container detected (category): Lex
# Container detected (category): Link Hotel
# Container detected (category): Lloyds Inn
# Container detected (category): Naumi Liora
# Container detected (category): Naumi
# Container detected (category): New Cape Inn
# Container detected (category): New Cathay Hotel (Geylang)
# Container detected (category): JXIN Hotel
# Container detected (category): New Majestic Hotel
# Container detected (category): New Orchid Hotel
# Container detected (category): Dream Lodge
# Container detected (category): Nostalgia Hotel
# Container detected (category): Oasia Hotel
# Container detected (category): One Farrer Hotel & Spa
# Container detected (category): Orchard Hotel Singapore
# Container detected (category): Orchard RendezVous Hotel
# Container detected (category): Orchid Hotel
# Container detected (category): K Hotel 14
# Container detected (category): K Hotel 12
# Container detected (category): Parc Sovereign Hotel (Tyrwhitt)
# Container detected (category): Amoy Hotel
# Container detected (category): Amrise Hotel
# Container detected (category): Aqueen Hotel (Lavender)
# Container detected (category): Arcadia Hotel
# Container detected (category): Arianna Hotel
# Container detected (category): Arton Boutique Hotel
# Container detected (category): Ascott
# Container detected (category): Asia Star Hotel
# Container detected (category): Backpacker Cozy Corner Guesthouse
# Container detected (category): Backpackers (Inn Chinatown 2)
# Container detected (category): Backpackers (Inn Chinatown 3)
# Container detected (category): Backpackers Inn Chinatown
# Container detected (category): Backpackerssg
# Container detected (category): Local
# Container detected (category): Beds and Dreams
# Container detected (category): Hotel Lyf Bugis
# Container detected (category): Blanc Inn
# Container detected (category): Bliss Hotel
# Container detected (category): Blissful Loft
# Container detected (category): Bright Star Hotel
# Container detected (category): Broadway Hotel
# Container detected (category): Budgetone Hotel
# Container detected (category): Cameron Hotel
# Container detected (category): Capella Singapore
# Container detected (category): Dorsett Changi City Singapore
# Container detected (category): Carlton Hotel
# Container detected (category): Champion Hotel
# Container detected (category): Chang Ziang Hotel
# Container detected (category): Checkers Backpackers
# Container detected (category): Cherryloft Resorts
# Container detected (category): Soloha
# Container detected (category): Concorde Hotel Singapore
# Container detected (category): Conrad Centennial Singapore
# Container detected (category): Copthorne King Hotel
# Container detected (category): The Room Capsule Hotel
# Container detected (category): Crowne Plaza (Changi Airport)
# Container detected (category): Holiday Inn Express Singapore Serangoon
# Container detected (category): Darlene Hotel (Geylang)
# Container detected (category): Aloft
# Container detected (category): K Hotel 8
# Container detected (category): Holiday Inn (Atrium)
# Container detected (category): Holiday Inn (Orchard City Centre)
# Container detected (category): Holiday Inn Express (Orchard Road)
# Container detected (category): Hoover Hotel
# Container detected (category): Hotel 165
# Container detected (category): hotel 1929
# Container detected (category): Hotel 81 (Balestier)
# Container detected (category): Hotel 81
# Container detected (category): Hotel 81 (Cherry)
# Container detected (category): Hotel 81 (Classic)
# Container detected (category): Hotel 81 (Cosy)
# Container detected (category): Hotel 81 (Dickson)
# Container detected (category): Hotel 81 (Elegance)
# Container detected (category): Hotel 81 (Gold)
# Container detected (category): Lofi Inn
# Container detected (category): Lulu Hotel
# Container detected (category): M Social Singapore
# Container detected (category): Malacca Hotel
# Container detected (category): Hilton Singapore Orchard
# Container detected (category): Mandarin Oriental Singapore
# Container detected (category): Marina Bay Sands
# Container detected (category): Fragrance Hotel (Balestier)
# Container detected (category): Fragrance Hotel (Classic)
# Container detected (category): Ibis Budget Singapore Crystal
# Container detected (category): Fragrance Hotel (Imperial)
# Container detected (category): Fragrance Hotel (Ocean View)
# Container detected (category): Fragrance Hotel (Rose)
# Container detected (category): Fragrance Hotel (Royal)
# Container detected (category): Ibis Budget Singapore Ruby
# Container detected (category): Ibis Budget Singapore Sapphire
# Container detected (category): Ibis Budget Singapore Ametrine
# Container detected (category): Fragrance Hotel (Viva)
# Container detected (category): Fragrance Hotel (Waterfront)
# Container detected (category): Furama Riverfront Singapore
# Container detected (category): Gay World Hotel
# Container detected (category): Genting Hotel (Jurong)
# Container detected (category): RedDoorz
# Container detected (category): Golden Royal Hotel
# Container detected (category): Golden Star Hotel
# Container detected (category): Goodwood Park Hotel
# Container detected (category): Grand Copthorne Waterfront Hotel
# Container detected (category): Grand Hyatt Singapore
# Container detected (category): Grand Mercure Roxy Hotel
# Container detected (category): Grand Park City Hall
# Container detected (category): Pullman Singapore Orchard
# Container detected (category): Gusti Bed and Breakfast
# Container detected (category): Haising Hotel
# Container detected (category): Hangout  Mt. Emily
# Container detected (category): Harbour Ville Hotel
# Container detected (category): Hotel 81 (Heritage)
# Container detected (category): Hotel 81 (Hollywood)
# Container detected (category): Hotel 81 (Joy)
# Container detected (category): Hotel 81 (Lavender)
# Container detected (category): Hotel 81 (Lucky)
# Container detected (category): Hotel 81 (Osaka)
# Container detected (category): Hotel 81 (Princess)
# Container detected (category): Hotel 81 (Spring)
# Container detected (category): Hotel 81 (Star)
# Container detected (category): Hotel 81 (Tristar)
# Container detected (category): Hotel 81 (Violet)
# Container detected (category): DNova HotelKallang
# Container detected (category): Hotel Bencoolen (Bencoolen Street)
# Container detected (category): Hotel Bencoolen (Hong Kong Street)
# Container detected (category): Hotel Chancellor
# Container detected (category): Hotel By Wassies
# Container detected (category): Aloft
# Container detected (category): Regin Hotel
# Container detected (category): Rendezvous Hotel Singapore
# Container detected (category): Riders Lodge
# Container detected (category): River City Inn
# Container detected (category): Royal India Hotel
# Container detected (category): Royal Plaza
# Container detected (category): Rucksack Inn (Lavender)
# Container detected (category): Rucksack Inn (Mackenzie)
# Container detected (category): Sandpiper Hotel
# Container detected (category): Rest Bugis
# Container detected (category): Santa Grand Hotel
# Container detected (category): Santa Grand Hotel (Lai Chun Yuen)
# Container detected (category): Santa Grand Hotel (Little India)
# Container detected (category): Santa Grand Hotel (West Coast)
# Container detected (category): Sheraton Towers Singapore
# Container detected (category): Singapore Marriott Tang Plaza Hotel
# Container detected (category): Marrison  Desker
# Container detected (category): the snooze hotel
# Container detected (category): Mayo Inn
# Container detected (category): Meng Yew Hotel
# Container detected (category): Atlantis531
# Container detected (category): RedDoorz Little India
# Container detected (category): Park 22 Hotel
# Container detected (category): Park Avenue Changi
# Container detected (category): Park Avenue Rochester
# Container detected (category): Park Hotel (Alexandra)
# Container detected (category): Novotel Singapore on Kitchener
# Container detected (category): Coliwoo Hotel Pasir Panjang
# Container detected (category): Peninsula Excelsior Hotel
# Container detected (category): Penta Hotel
# Container detected (category): Perak Hotel
# Container detected (category): Phil Inn
# Container detected (category): Pillows & Toast Heritage
# Container detected (category): Plush Pods
# Container detected (category): Porcelain Hotel
# Container detected (category): Quarters
# Container detected (category): RELC International Hotel
# Container detected (category): RM Hotel
# Container detected (category): The Fullerton Bay Hotel
# Container detected (category): The Inn
# Container detected (category): The Keong Saik Hotel
# Container detected (category): The Mitraa
# Container detected (category): The Noble Hotel
# Container detected (category): The Pan Pacific Hotel Singapore
# Container detected (category): The Pod
# Container detected (category): The Quincy Hotel
# Container detected (category): The Scarlet Hotel
# Container detected (category): The Seacare Hotel
# Container detected (category): The Westin Singapore
# Container detected (category): Travellersg
# Container detected (category): Simpang De Bedok Boarding House
# Container detected (category): Sing Hoe
# Container detected (category): Sloane Court Hotel
# Container detected (category): Sofitel Sentosa Resort & Spa
# Container detected (category): Strand Hotel
# Container detected (category): Studio M Hotel
# Container detected (category): JH Hotel
# Container detected (category): Tai Hoe Hotel
# Container detected (category): Taipei Hotel (2000)
# Container detected (category): HI Hotel Bugis
# Container detected (category): The Club
# Container detected (category): The Daulat
# Container detected (category): The Duxton
# Container detected (category): Vibe Hotel Singapore Orchard
# Container detected (category): V Hotel Bencoolen
# Container detected (category): V Hotel Lavender
# Container detected (category): VIP Hotel
# Container detected (category): Value Hotel (Balestier)
# Container detected (category): Value Hotel (Nice)
# Container detected (category): Value Hotel (Thomson)
# Container detected (category): Venue Hotel The Lily
# Container detected (category): Victoria Hotel
# Container detected (category): Wanderlust Hotel
# Container detected (category): DHotel
# Container detected (category): Yes Chinatown Pt. Hotel
# Container detected (category): Yew Lian Hotel
# Container detected (category): York Hotel
# Container detected (category): iStay.inn
# Container detected (category): 5footway.inn (Ann Siang)
# Container detected (category): 5footway.inn
# Container detected (category): 5footway.inn (Chinatown 1)
# Container detected (category): Heritage Collection on Chinatown
# Container detected (category): 5footway.inn (Chinatown 3)
# Container detected (category): 5footway.inn (Chinatown 4)
# Container detected (category): ChancellorOrchard
# Container detected (category): Hovo
# Container detected (category): Grand Shanghai
# Container detected (category): The Platinum
# Container detected (category): Yan Hotel
# Container detected (category): Sofitel Singapore City Centre
# Container detected (category): The St. Regis Singapore
# Container detected (category): DResort  Downtown East
# Container detected (category): Courtyard Singapore Novena
# Container detected (category): Hotel Telegraph
# Container detected (category): Campbell Inn
# Container detected (category): Hotel Traveltine
# Container detected (category): ONE15 Marina Sentosa Cove
# Container detected (category): YSUN Homestay
# Container detected (category): Dusit Thani Laguna Singapore
# Container detected (category): Hotel Miramar Singapore
# Container detected (category): Hotel NuVe Urbane
# Container detected (category): Mercure ICON Singapore City Centre
# Container detected (category): five/6 Hotel Splendour
# Container detected (category): Ibis Budget Bugis
# Container detected (category): Hotel 81
# Container detected (category): Hotel Boss
# Container detected (category): JW Marriott Hotel Singapore South Beach
# Container detected (category): Shipping Container Hotel
# Container detected (category): SpacePod hive
# Container detected (category): Lion Peak Hotel Hamilton
# Container detected (category): Raffles Hotel
# Container detected (category): Wink Hotel
# Container detected (category): Shipping Container Hotel
# Container detected (category): Venue Hotel
# Container detected (category): Hotel Clover 7
# Container detected (category): Hotel 81 Chinatown
# Container detected (category): InterContinental Singapore
# Container detected (category): Hotel Grand Central
# Container detected (category): Hotel Supreme
# Container detected (category): Holiday Inn Singapore Orchard City Centre
# Container detected (category): Concorde Hotel
# Container detected (category): The Fullerton Hotel
# Container detected (category): PARKROYAL on Beach Road
# Container detected (category): M Hotel Singapore
# Container detected (category): Costa Sands Resort (Sentosa)
# Container detected (category): Oasis Resort Sentosa
# Container detected (category): South East Asia Hotel
# Container detected (category): Travelodge Harbourfront Singapore
# Container detected (category): Labrador Villa
# Container detected (category): Pullman Singapore HIll Street
# Container detected (category): Hard Rock Hotel Singapore
# Container detected (category): Hotel Michael
# Container detected (category): Hotel 81 (Palace)
# Container detected (category): Yaju Hotel
# Container detected (category): Hotel 81 Orchid
# Container detected (category): Hotel Mi Rochor
# Container detected (category): Yotel Singapore Orchard Road
# Container detected (category): Pan Pacific Orchard
# Container detected (category): Oxford Hotel
# Container detected (category): Hotel Ora
# Container detected (category): Crockfords Tower
# Container detected (category): Ji Hotel Orchard
# Container detected (category): Swisstel The Stamford
# Container detected (category): voco Orchard Singapore
# Container detected (category): Hotel Grand Pacific
# Container detected (category): Summer View Hotel
# Container detected (category): Hotel Mi
# Container detected (category): Jayleen Clarke Quay Hotel
# Container detected (category): 21 Carpenter
# Container detected (category): The Novelty House
# Container detected (category): ibis Budget Hotel Clarke Quay
# Container detected (category): Champion Hotel City
# Container detected (category): Jayleen 1918 Hotel
# Container detected (category): ST Signature Tanjong Pagar
# Container detected (category): Maxwell Reserve
# Container detected (category): Fraser Suites
# Container detected (category): Village Hotel (Changi)
# Container detected (category): Hotel 81 (Rochor)
# Container detected (category): Siloso Beach Resort
# Container detected (category): Hilton Garden Inn Singapore Serangoon
# Container detected (category): Aliwal Park Hotel
# Container detected (category): 5footway.inn (Bugis)
# Container detected (category): 5footway.inn (Bugis)
# Container detected (category): Weave Suites Midtown
# Container detected (category): Weave Suites Midtown
# Container detected (category): Hotel Clover (Jalan Sultan)
# Container detected (category): Weave Suites Midtown
# Container detected (category): Hotel Clover (Jalan Sultan)
# Container detected (category): Weave Suites Midtown
# Container detected (category): Weave Suites Midtown
# Container detected (category): Weave Suites Midtown
# Container detected (category): Hotel Clover (Jalan Sultan)
# Container detected (category): Weave Suites Midtown
# Container detected (category): Weave Suites Midtown
# Container detected (category): Hotel Clover (Jalan Sultan)
# Container detected (category): Weave Suites Midtown
# Container detected (category): Hotel Clover (Jalan Sultan)
# Container detected (category): Hotel Clover (Jalan Sultan)
# Container detected (category): Weave Suites Midtown
# Container detected (category): Hotel Clover (Jalan Sultan)
# Container detected (category): Cube Hotel
# Container detected (category): 5footway.inn (Bugis)
# Container detected (category): Village Hotel (Bugis)
# Container detected (category): The Sultan
# Container detected (category): Royal India Hotel
# Container detected (category): ibis Singapore Novena
# Container detected (category): ST Residences Novena
# Container detected (category): Village Hotel (Katong)
# Container detected (category): Aqueen Hotel (Paya Lebar)
# Container detected (category): Ibis Budget Selegie
# Container detected (category): Hotel 81 (Selegie)
# Container detected (category): Hotel 81 (Kovan)
# Container detected (category): Park View Hotel
# Container detected (category): ST Signature
# Container detected (category): Orchard Hills Residences Singapore MGallery
# Container detected (category): Habyt Novena
# Container detected (category): Fragrance Hotel (Oasis)
# Container detected (category): Holiday Inn Express & Suites
# Container detected (category): Hotel 81 (Fuji)
# Container detected (category): Aqueen Hotel (Balestier)
# Container detected (category): Ibis Budget Joo Chiat
# Container detected (category): Hotel 81 (Sakura)
# Container detected (category): Conrad Singapore Orchard
# Container detected (category): ISA Hotel
# Container detected (category): Mercure
# Container detected (category): Ibis Styles
# Container detected (category): Hotel Nuve Stellar
# Container detected (category): Holiday Inn Express Singapore Clarke Quay
# Container detected (category): Oasia Hotel (Downtown)
# Container detected (category): Lai Ming Hotel
# Container detected (category): Seng Wah Hotel
# Container detected (category): Min Wah Hotel
# Container detected (category): Kim Tian Hotel
# Container detected (category): The Serangoon House
# Container detected (category): Classique Hotel
# Container detected (category): Aqueen Prestige Hotel Lavender
# Container detected (category): Aqueen Prestige Hotel Jalan Besar
# Container detected (category): Asphodel Inn
# Container detected (category): Oxley Hotel
# Container detected (category): Ibis Budget Singapore Emerald
# Container detected (category): Ibis budget Singapore Pearl
# Container detected (category): Lemon Grass
# Container detected (category): The Warehouse
# Container detected (category): Paradox Singapore Merchant Court at Clarke Quay
# Container detected (category): Carlton City Hotel
# Container detected (category): The Amazing Inn
# Container detected (category): Fragrance Hotel (Kovan)
# Container detected (category): Equarius Hotel
# Container detected (category): Ascott Orchard Singapore
# Container detected (category): Holiday Inn Express Katong
# Container detected (category): Novotel Living Singapore Orchard
# Container detected (category): Shangri-Las Rasa Sentosa Resort & Spa
# Container detected (category): Park Regis
# Container detected (category): Parkroyal Collection Marina Bay
# Container detected (category): YotelAir Changi
# Container detected (category): Village Hotel  Sentosa
# Container detected (category): The Robertson House by The Crest Collection
# Container detected (category): The Barracks Hotel
# Container detected (category): Mercure Singapore On Stevens
# Container detected (category): Novotel Singapore On Stevens
# Container detected (category): Shangri-La Hotel Singapore
# Container detected (category): Changi Cove
# Container detected (category): Raintr33 Hotel Singapore
# Container detected (category): Village Hotel Albert Court
# Container detected (category): Hotel Faber Park
# Container detected (category): Citadines Science Park Singapore
# Container detected (category): Hotel Fort Canning
# Container detected (in address): The Centrepoint
# Container detected (in address): The Clementi Mall
# Container detected (in address): Tampines Mall
# Container detected (in address): Tampines 1
# Container detected (partial match): Joo Chiat
# Container detected (partial match): Boulevard
# Container detected (in address): Waterway Point
# Container detected (in address): Northpoint City
# Container detected (in address): The Seletar Mall
# Container detected (in address): Westgate
# Container detected (in address): Century Square
# Container detected (partial match): Yio Chu Kang
# Container detected (in address): Funan
# Container detected (in address): Bugis Junction
# Container detected (in address): Paragon
# Container detected (in address): Cluny Court
# Container detected (partial match): Hong Kong
# Container detected (in address): Clarke Quay Central
# Container detected (partial match): Takashimaya
# Container detected (in address): VivoCity
# Container detected (partial match): Lavender
# Container detected (in address): Plaza Singapura
# Container detected (in address): Suntec City
# Container detected (in address): nex
# Container detected (in address): Jurong Point
# Container detected (in address): IMM
# Container detected (in address): The Star Vista
# Container detected (in address): United Square
# Container detected (in address): FairPrice
#
# Total containers found: 710
#
# === Step 2: Mapping POIs to Containers ===
# Mapped 1104 POIs to containers
#
# === Building Level 0: Individual POIs ===
# Created 4696 individual POIs
#
# === Building Level 1: Containers & Street Clusters ===
# Created 1355 Level 1 nodes (710 containers, 645 street clusters)
#
# === Building Level 2: Districts ===
# Created 44 districts
#
# === Building Level 3: Regions ===
# Created 5 regions
#
# ============================================================
# POI Tree Construction Complete!
# ============================================================
#
# Tree Summary:
#   Level 0 (Individual POIs): 4696 nodes
#   Level 1 (Containers/Streets): 1355 nodes
#   Level 2 (Districts): 44 nodes
#   Level 3 (Regions): 5 nodes
#   Total nodes: 6100
#
# Tree saved to poi_tree.json
#
# === Sample Tree Paths ===
#
# L3: CENTRAL → L2: GEYLANG → L1: Paya Lebar Square (container_poi) → L0: Giant
#
# L3: WEST → L2: CHOA CHU KANG → L1: Limbang Shopping Centre (container_poi) → L0: NTUC FairPrice
#
# L3: WEST → L2: CHOA CHU KANG → L1: Limbang Shopping Centre (container_poi) → L0: NTUC FairPrice
#
# L3: CENTRAL → L2: GEYLANG → L1: Paya Lebar Square (container_poi) → L0: Giant
#
# L3: EAST → L2: BEDOK → L1: Bedok Road (street_cluster) → L0: Giant Hypermarket
#
# Found 'Din Tai Fung' at level_0
#   Location: (1.3342935, 103.8893341)
#   Parent: container_Velocity__Novena_Square
#   Ancestors: ['Velocity  Novena Square', 'NOVENA', 'CENTRAL']
#
# Found 'Suntec City' at level_1
#   Type: container_poi
#   Children: 4
#   Total descendants: 4

# %%
import uuid

def add_uuids_to_tree(builder):
    """
    Add UUIDs to all nodes in existing tree
    
    Args:
        builder: POITreeBuilder instance with built tree
    """
    print("Adding UUIDs to existing tree...")
    
    uuid_map = {}  # Maps old IDs to UUIDs for reference
    
    for level_name, level_nodes in builder.tree.items():
        print(f"\nProcessing {level_name}...")
        for node_id, node_data in level_nodes.items():
            # Generate UUID
            new_uuid = str(uuid.uuid4())
            
            # Add UUID to node data
            node_data['uuid'] = new_uuid
            
            # Store mapping
            uuid_map[node_id] = new_uuid
        
        print(f"Added UUIDs to {len(level_nodes)} nodes in {level_name}")
    
    print("\n✓ UUIDs added successfully!")
    return uuid_map

# Usage:
uuid_map = add_uuids_to_tree(builder)

# Save updated tree
builder.save_tree('poi_tree_with_uuids.json')

# Verify
sample_poi = list(builder.tree['level_0'].values())[0]
print(f"\nSample POI with UUID: {sample_poi['name']}")
print(f"UUID: {sample_poi['uuid']}")
# Out:
# Adding UUIDs to existing tree...
#
# Processing level_0...
# Added UUIDs to 4696 nodes in level_0
#
# Processing level_1...
# Added UUIDs to 1355 nodes in level_1
#
# Processing level_2...
# Added UUIDs to 44 nodes in level_2
#
# Processing level_3...
# Added UUIDs to 5 nodes in level_3
#
# ✓ UUIDs added successfully!
#
# Tree saved to poi_tree_with_uuids.json
#
# Sample POI with UUID: Giant
# UUID: d401dde1-0898-43b2-ae19-0f2c3634f7d0
